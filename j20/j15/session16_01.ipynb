# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('data.csv')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 5        NaN           NaN       NaN              NaN         NaN          NaN
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 8       45.0           NaN        AF              NaN         8.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# ...

# %%
df.head()
# Out:
#    Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0      30.0            80       120            240.0        10.0          7.0
# 1      45.0            85       120            250.0        10.0          7.0
# 2      45.0            90       130            260.0         8.0          7.0
# 3      60.0            95       130            270.0         8.0          7.0
# 4      60.0           100       140            280.0         0.0          7.0

# %%
df.head(10)
# Out:
#    Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0      30.0            80       120            240.0        10.0          7.0
# 1      45.0            85       120            250.0        10.0          7.0
# 2      45.0            90       130            260.0         8.0          7.0
# 3      60.0            95       130            270.0         8.0          7.0
# 4      60.0           100       140            280.0         0.0          7.0
# 5       NaN           NaN       NaN              NaN         NaN          NaN
# 6      60.0           105       140            290.0         7.0          8.0
# 7      60.0           110       145            300.0         7.0          8.0
# 8      45.0           NaN        AF              NaN         8.0          8.0
# 9      45.0           115       145            310.0         8.0          8.0

# %%
df.tail()
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# 11      60.0         9 000       130              NaN         NaN          8.0
# 12      45.0           125       150            330.0         8.0          8.0
# 13   12000.0           125       150            330.0         8.0          8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         13 non-null     float64
#  1   Average_Pulse    12 non-null     object
#  2   Max_Pulse        13 non-null     object
#  3   Calorie_Burnage  11 non-null     float64
#  4   Hours_Work       12 non-null     float64
#  5   Hours_Sleep      13 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 800.0+ bytes

# %%
df.describe()
# Out:
#            Duration  Calorie_Burnage  Hours_Work  Hours_Sleep
# count     13.000000        11.000000   12.000000    13.000000
# mean     970.384615       289.090909    6.833333     7.615385
# std     3314.000894        31.766191    3.325749     0.506370
# min       30.000000       240.000000    0.000000     7.000000
# 25%       45.000000       265.000000    7.000000     7.000000
# 50%       60.000000       290.000000    8.000000     8.000000
# 75%       60.000000       315.000000    8.000000     8.000000
# max    12000.000000       330.000000   10.000000     8.000000

# %%
df.drop(columns=['Duration'])
# Out:
#    Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0             80       120            240.0        10.0          7.0
# 1             85       120            250.0        10.0          7.0
# 2             90       130            260.0         8.0          7.0
# 3             95       130            270.0         8.0          7.0
# 4            100       140            280.0         0.0          7.0
# 5            NaN       NaN              NaN         NaN          NaN
# 6            105       140            290.0         7.0          8.0
# 7            110       145            300.0         7.0          8.0
# 8            NaN        AF              NaN         8.0          8.0
# 9            115       145            310.0         8.0          8.0
# 10           120       150            320.0         0.0          8.0
# 11         9 000       130              NaN         NaN          8.0
# 12           125       150            330.0         8.0          8.0
# ...

# %%
df.head()
# Out:
#    Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0      30.0            80       120            240.0        10.0          7.0
# 1      45.0            85       120            250.0        10.0          7.0
# 2      45.0            90       130            260.0         8.0          7.0
# 3      60.0            95       130            270.0         8.0          7.0
# 4      60.0           100       140            280.0         0.0          7.0

# %%
#df.drop(columns=['Duration'], inplace=True)

df_without_Duration=df.drop(columns=['Duration'])

# %%
df_without_Duration.head()
# Out:
#   Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0            80       120            240.0        10.0          7.0
# 1            85       120            250.0        10.0          7.0
# 2            90       130            260.0         8.0          7.0
# 3            95       130            270.0         8.0          7.0
# 4           100       140            280.0         0.0          7.0

# %%
df.shape
# Out:
# (14, 6)

# %%
df.isnull().sum()
# Out:
# Duration           1
# Average_Pulse      2
# Max_Pulse          1
# Calorie_Burnage    3
# Hours_Work         2
# Hours_Sleep        1
# dtype: int64

# %%
df.shape[0]
# Out:
# 14

# %%
round((df.isnull().sum()/df.shape[0])*100, 2)
# Out:
# Duration            7.14
# Average_Pulse      14.29
# Max_Pulse           7.14
# Calorie_Burnage    21.43
# Hours_Work         14.29
# Hours_Sleep         7.14
# dtype: float64

# %%
df.dropna(subset=['Duration'], axis=0)
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 8       45.0           NaN        AF              NaN         8.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# 11      60.0         9 000       130              NaN         NaN          8.0
# ...

# %%
df
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 5        NaN           NaN       NaN              NaN         NaN          NaN
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 8       45.0           NaN        AF              NaN         8.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# ...

# %%
df.fillna(111)
# Out:
#     Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0       30.0            80       120            240.0        10.0          7.0
# 1       45.0            85       120            250.0        10.0          7.0
# 2       45.0            90       130            260.0         8.0          7.0
# 3       60.0            95       130            270.0         8.0          7.0
# 4       60.0           100       140            280.0         0.0          7.0
# 5      111.0           111       111            111.0       111.0        111.0
# 6       60.0           105       140            290.0         7.0          8.0
# 7       60.0           110       145            300.0         7.0          8.0
# 8       45.0           111        AF            111.0         8.0          8.0
# 9       45.0           115       145            310.0         8.0          8.0
# 10      60.0           120       150            320.0         0.0          8.0
# ...

# %%
df['Duration'].fillna(df.Duration.mean())
# Out:
# 0      30.000000
# 1      45.000000
# 2      45.000000
# 3      60.000000
# 4      60.000000
# 5      60.133333
# 6      40.000000
# 7      60.000000
# 8      45.000000
# 9      45.000000
# 10     60.000000
# 11     30.000000
# 12     45.000000
# 13    120.000000
# 14    118.000000
# 15     99.000000
# Name: Duration, dtype: float64

# %%
df.Duration.mean()
# Out:
# 970.3846153846154

# %%
df['Duration'].fillna(df.Duration.mean(), inplace=True)

# %%
plt.boxplot(df['Duration'], vert=False)
plt.ylabel('Variable')
plt.xlabel('Duration')
plt.title('Box Plot for outlier reconziation')
plt.show()

# %%
df_new=df[df['Duration']<=70]

# %%
df_new
# Out:
#      Duration Average_Pulse Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0   30.000000            80       120            240.0        10.0
# 1   45.000000            85       120            250.0        10.0
# 2   45.000000            90       130            260.0         8.0
# 3   60.000000            95       130            270.0         8.0
# 4   60.000000           100       140            280.0         0.0
# 5   63.466667           NaN       NaN              NaN         NaN
# 6   60.000000           105       140            290.0         7.0
# 7   60.000000           110       145            300.0         7.0
# 8   45.000000           NaN        AF              NaN         8.0
# 9   45.000000           115       145            310.0         8.0
# 10  60.000000           120       150            320.0         0.0
# 11  60.000000         9 000       130              NaN         NaN
# 12  45.000000           125       150            330.0         8.0
#
#     Hours_Sleep
# ...

# %%
plt.boxplot(df_new['Duration'], vert=False)
plt.ylabel('Variable')
plt.xlabel('Duration')
plt.title('Box Plot for outlier reconziation')
plt.show()

# %%
df.Duration.std()
# Out:
# 28.059143884936255

# %%
df_new.Duration.std()
# Out:
# 11.106000534091823

# %% [markdown]
# ## This is a test

# %% [markdown]
# Columns: Article, Sales, WeekDay, Month
#
# scatterplot for 2 dimentions
#
# bar
#
# pie
#
# plot
#
# median, mean, std,mode
#
# boxplot
